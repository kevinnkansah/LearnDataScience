# %%
library(readr)
library(tidyr)
library(plyr)
library(dplyr)
library(ggplot2)

# %%
df <- read_csv("data/games.csv", show_col_types = FALSE)
head(df)
# Out:
#   GAME_DATE_EST GAME_ID  GAME_STATUS_TEXT HOME_TEAM_ID VISITOR_TEAM_ID SEASON
# 1 2022-12-22    22200477 Final            1610612740   1610612759      2022
# 2 2022-12-22    22200478 Final            1610612762   1610612764      2022
# 3 2022-12-21    22200466 Final            1610612739   1610612749      2022
# 4 2022-12-21    22200467 Final            1610612755   1610612765      2022
# 5 2022-12-21    22200468 Final            1610612737   1610612741      2022
# 6 2022-12-21    22200469 Final            1610612738   1610612754      2022
#   TEAM_ID_home PTS_home FG_PCT_home FT_PCT_home ⋯ AST_home REB_home
# 1 1610612740   126      0.484       0.926       ⋯ 25       46
# 2 1610612762   120      0.488       0.952       ⋯ 16       40
# 3 1610612739   114      0.482       0.786       ⋯ 22       37
# 4 1610612755   113      0.441       0.909       ⋯ 27       49
# 5 1610612737   108      0.429       1.000       ⋯ 22       47
# ...

# %%
df$GAME_DATE_EST
# Out:
#     [1] "2022-12-22" "2022-12-22" "2022-12-21" "2022-12-21" "2022-12-21"
#     [6] "2022-12-21" "2022-12-21" "2022-12-21" "2022-12-21" "2022-12-21"
#    [11] "2022-12-21" "2022-12-21" "2022-12-21" "2022-12-20" "2022-12-20"
#    [16] "2022-12-20" "2022-12-20" "2022-12-20" "2022-12-19" "2022-12-19"
#    [21] "2022-12-19" "2022-12-19" "2022-12-19" "2022-12-19" "2022-12-19"
#    [26] "2022-12-19" "2022-12-19" "2022-12-18" "2022-12-18" "2022-12-18"
#    [31] "2022-12-18" "2022-12-18" "2022-12-18" "2022-12-18" "2022-12-17"
#    [36] "2022-12-17" "2022-12-17" "2022-12-17" "2022-12-17" "2022-12-17"
#    [41] "2022-12-17" "2022-12-16" "2022-12-16" "2022-12-16" "2022-12-16"
#    [46] "2022-12-16" "2022-12-16" "2022-12-16" "2022-12-16" "2022-12-16"
#    [51] "2022-12-16" "2022-12-15" "2022-12-15" "2022-12-15" "2022-12-15"
#    [56] "2022-12-14" "2022-12-14" "2022-12-14" "2022-12-14" "2022-12-14"
#    [61] "2022-12-14" "2022-12-14" "2022-12-14" "2022-12-14" "2022-12-14"
# ...
