# %%
library(readr)
library(tidyr)
library(plyr)
library(dplyr)
library(ggplot2)

# %%
basketball_data <- read_csv("data/games.csv", show_col_types = FALSE)
basketball_data
# Out:
#       GAME_DATE_EST GAME_ID  GAME_STATUS_TEXT HOME_TEAM_ID VISITOR_TEAM_ID
# 1     2022-12-22    22200477 Final            1610612740   1610612759
# 2     2022-12-22    22200478 Final            1610612762   1610612764
# 3     2022-12-21    22200466 Final            1610612739   1610612749
# 4     2022-12-21    22200467 Final            1610612755   1610612765
# 5     2022-12-21    22200468 Final            1610612737   1610612741
# 6     2022-12-21    22200469 Final            1610612738   1610612754
# 7     2022-12-21    22200470 Final            1610612751   1610612744
# 8     2022-12-21    22200471 Final            1610612752   1610612761
# 9     2022-12-21    22200472 Final            1610612745   1610612753
# 10    2022-12-21    22200473 Final            1610612750   1610612742
# 11    2022-12-21    22200474 Final            1610612760   1610612757
# 12    2022-12-21    22200475 Final            1610612758   1610612747
# ...

# %%
selected_data <- basketball_data %>%
  select(GAME_DATE_EST, GAME_ID, HOME_TEAM_ID, VISITOR_TEAM_ID, SEASON, PTS_home, FG_PCT_home, FT_PCT_home, AST_home, REB_home, HOME_TEAM_WINS)
selected_data
# Out:
#       GAME_DATE_EST GAME_ID  HOME_TEAM_ID VISITOR_TEAM_ID SEASON PTS_home
# 1     2022-12-22    22200477 1610612740   1610612759      2022   126
# 2     2022-12-22    22200478 1610612762   1610612764      2022   120
# 3     2022-12-21    22200466 1610612739   1610612749      2022   114
# 4     2022-12-21    22200467 1610612755   1610612765      2022   113
# 5     2022-12-21    22200468 1610612737   1610612741      2022   108
# 6     2022-12-21    22200469 1610612738   1610612754      2022   112
# 7     2022-12-21    22200470 1610612751   1610612744      2022   143
# 8     2022-12-21    22200471 1610612752   1610612761      2022   106
# 9     2022-12-21    22200472 1610612745   1610612753      2022   110
# 10    2022-12-21    22200473 1610612750   1610612742      2022    99
# 11    2022-12-21    22200474 1610612760   1610612757      2022   101
# 12    2022-12-21    22200475 1610612758   1610612747      2022   134
# 13    2022-12-21    22200476 1610612746   1610612766      2022   126
# ...

# %%
filtered_data <- basketball_data %>%
  filter(SEASON == 2022)
filtered_data
# Out:
#     GAME_DATE_EST GAME_ID  GAME_STATUS_TEXT HOME_TEAM_ID VISITOR_TEAM_ID SEASON
# 1   2022-12-22    22200477 Final            1610612740   1610612759      2022
# 2   2022-12-22    22200478 Final            1610612762   1610612764      2022
# 3   2022-12-21    22200466 Final            1610612739   1610612749      2022
# 4   2022-12-21    22200467 Final            1610612755   1610612765      2022
# 5   2022-12-21    22200468 Final            1610612737   1610612741      2022
# 6   2022-12-21    22200469 Final            1610612738   1610612754      2022
# 7   2022-12-21    22200470 Final            1610612751   1610612744      2022
# 8   2022-12-21    22200471 Final            1610612752   1610612761      2022
# 9   2022-12-21    22200472 Final            1610612745   1610612753      2022
# 10  2022-12-21    22200473 Final            1610612750   1610612742      2022
# 11  2022-12-21    22200474 Final            1610612760   1610612757      2022
# ...

# %%
mutated_data <- basketball_data %>%
  mutate(POINTS_DIFF = PTS_home - PTS_away)
mutated_data
# Out:
#       GAME_DATE_EST GAME_ID  GAME_STATUS_TEXT HOME_TEAM_ID VISITOR_TEAM_
# 11 1610612747         NA
# 12 1610612748         NA
# 13 1610612749         NA
# 14 1610612750         NA
# 15 1610612751         NA
# 16 1610612752         NA
# 17 1610612753         NA
# 18 1610612754         NA
# 19 1610612755         NA
# 20 1610612756         NA
# 21 1610612757         NA
# 22 1610612758         NA
# 23 1610612759         NA
# 24 1610612760         NA
# 25 1610612761         NA
# 26 1610612762         NA
# 27 1610612763         NA
# 28 1610612764         NA
# 29 1610612765         NA
# 30 1610612766   100.6203

# %%
stuff <- data.frame(
    Name = c("Kevin", "Bob", "Percy", "Gabe", "Jeff"), 
    Age = c(19, 41, 64, 74, 55), 
    FavColor = c("Green", "Orange", "Yellow", "Green", "Blue"), 
    GoatNBAPlayer = c("MJ", "Steph", "Iguaduala", "KG", "CP3")
)
stuff
# Out:
#   Name  Age FavColor GoatNBAPlayer
# 1 Kevin 19  Green    MJ
# 2 Bob   41  Orange   Steph
# 3 Percy 64  Yellow   Iguaduala
# 4 Gabe  74  Green    KG
# 5 Jeff  55  Blue     CP3

# %%
result <- stuff %>%
    select(Name, Age) %>%
    arrange(desc(Age))

result
# Out:
#   Name  Age
# 1 Gabe  74
# 2 Percy 64
# 3 Jeff  55
# 4 Bob   41
# 5 Kevin 19

# %%
head(stuff, 2)
# Out:
#   Name  Age FavColor GoatNBAPlayer
# 1 Kevin 19  Green    MJ
# 2 Bob   41  Orange   Steph

# %%
dim(stuff)
# Out:
# [1] 5 4

# %%
summary(stuff)
# Out:
#      Name                Age         FavColor         GoatNBAPlayer
#  Length:5           Min.   :19.0   Length:5           Length:5
#  Class :character   1st Qu.:41.0   Class :character   Class :character
#  Mode  :character   Median :55.0   Mode  :character   Mode  :character
#                     Mean   :50.6
#                     3rd Qu.:64.0
#                     Max.   :74.0

# %%
str(stuff)
# Out:
# 'data.frame':	5 obs. of  4 variables:
#  $ Name         : chr  "Kevin" "Bob" "Percy" "Gabe" ...
#  $ Age          : num  19 41 64 74 55
#  $ FavColor     : chr  "Green" "Orange" "Yellow" "Green" ...
#  $ GoatNBAPlayer: chr  "MJ" "Steph" "Iguaduala" "KG" ...

# %%
is.na(stuff)
# Out:
#      Name  Age   FavColor GoatNBAPlayer
# [1,] FALSE FALSE FALSE    FALSE
# [2,] FALSE FALSE FALSE    FALSE
# [3,] FALSE FALSE FALSE    FALSE
# [4,] FALSE FALSE FALSE    FALSE
# [5,] FALSE FALSE FALSE    FALSE

# %%
stuff <- rename(stuff, Color = FavColor)

stuff
# Out:
#   Name  Age Color  GoatNBAPlayer
# 1 Kevin 19  Green  MJ
# 2 Bob   41  Orange Steph
# 3 Percy 64  Yellow Iguaduala
# 4 Gabe  74  Green  KG
# 5 Jeff  55  Blue   CP3

# %%
yo <- seq(from=0, to=10, by=2)
ayo <- c(1, 2, 3, 4, 5, 6)
print(yo)
print(class(yo))
print(class(ayo))
# Out:
# [1]  0  2  4  6  8 10
# [1] "numeric"
# [1] "numeric"
