# %%
install.packages("plyr")
# Out:
# Installing package into 'C:/Users/User/AppData/Local/R/win-library/4.3'
# (as 'lib' is unspecified)
# package 'plyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\User\AppData\Local\Temp\RtmpKE3Dk1\downloaded_packages

# %%
library(readr)
library(tidyr)
library(plyr)
library(dplyr)
library(ggplot2)

# %%
basketball_data <- read_csv("data/games.csv", show_col_types = FALSE)

# %%
selected_data <- basketball_data %>%
  select(GAME_DATE_EST, GAME_ID, HOME_TEAM_ID, VISITOR_TEAM_ID, SEASON, PTS_home, FG_PCT_home, FT_PCT_home, AST_home, REB_home, HOME_TEAM_WINS)
selected_data
# Out:
#       GAME_DATE_EST GAME_ID  HOME_TEAM_ID VISITOR_TEAM_ID SEASON PTS_home
# 1     2022-12-22    22200477 1610612740   1610612759      2022   126
# 2     2022-12-22    22200478 1610612762   1610612764      2022   120
# 3     2022-12-21    22200466 1610612739   1610612749      2022   114
# 4     2022-12-21    22200467 1610612755   1610612765      2022   113
# 5     2022-12-21    22200468 1610612737   1610612741      2022   108
# 6     2022-12-21    22200469 1610612738   1610612754      2022   112
# 7     2022-12-21    22200470 1610612751   1610612744      2022   143
# 8     2022-12-21    22200471 1610612752   1610612761      2022   106
# 9     2022-12-21    22200472 1610612745   1610612753      2022   110
# 10    2022-12-21    22200473 1610612750   1610612742      2022    99
# 11    2022-12-21    22200474 1610612760   1610612757      2022   101
# 12    2022-12-21    22200475 1610612758   1610612747      2022   134
# 13    2022-12-21    22200476 1610612746   1610612766      2022   126
# ...

# %%
filtered_data <- basketball_data %>%
  filter(SEASON == 2022)
filtered_data
# Out:
#     GAME_DATE_EST GAME_ID  GAME_STATUS_TEXT HOME_TEAM_ID VISITOR_TEAM_ID SEASON
# 1   2022-12-22    22200477 Final            1610612740   1610612759      2022
# 2   2022-12-22    22200478 Final            1610612762   1610612764      2022
# 3   2022-12-21    22200466 Final            1610612739   1610612749      2022
# 4   2022-12-21    22200467 Final            1610612755   1610612765      2022
# 5   2022-12-21    22200468 Final            1610612737   1610612741      2022
# 6   2022-12-21    22200469 Final            1610612738   1610612754      2022
# 7   2022-12-21    22200470 Final            1610612751   1610612744      2022
# 8   2022-12-21    22200471 Final            1610612752   1610612761      2022
# 9   2022-12-21    22200472 Final            1610612745   1610612753      2022
# 10  2022-12-21    22200473 Final            1610612750   1610612742      2022
# 11  2022-12-21    22200474 Final            1610612760   1610612757      2022
# ...

# %%
fil
