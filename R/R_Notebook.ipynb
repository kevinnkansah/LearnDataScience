# %%
a <- c(4, 5, 6, 6, 66, 6)

# %%
install.packages('readr')
# Out:
# Installing package into 'C:/Users/Kevin Nkansah/AppData/Local/R/win-library/4.3'
# (as 'lib' is unspecified)
# package 'readr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Kevin Nkansah\AppData\Local\Temp\RtmpG6kKEP\downloaded_packages

# %%
library(readr)
# Out:
# Warning message:
# "package 'readr' was built under R version 4.3.1"

# %%
df <- read_csv('data/games.csv', show_col_types = FALSE)

# %%
df
# Out:
#       GAME_DATE_EST GAME_ID  GAME_STATUS_TEXT HOME_TEAM_ID VISITOR_TEAM_ID
# 1     2022-12-22    22200477 Final            1610612740   1610612759
# 2     2022-12-22    22200478 Final            1610612762   1610612764
# 3     2022-12-21    22200466 Final            1610612739   1610612749
# 4     2022-12-21    22200467 Final            1610612755   1610612765
# 5     2022-12-21    22200468 Final            1610612737   1610612741
# 6     2022-12-21    22200469 Final            1610612738   1610612754
# 7     2022-12-21    22200470 Final            1610612751   1610612744
# 8     2022-12-21    22200471 Final            1610612752   1610612761
# 9     2022-12-21    22200472 Final            1610612745   1610612753
# 10    2022-12-21    22200473 Final            1610612750   1610612742
# 11    2022-12-21    22200474 Final            1610612760   1610612757
# 12    2022-12-21    22200475 Final            1610612758   1610612747
# ...
